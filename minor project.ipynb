# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
dt=pd.read_csv('Minor_Project_Data_set_(Stock_Price_Prediction)[1](Stock Price dataset) (1).csv')
dt[['Open']]
# Out:
#             Open
# 0     262.000000
# 1     247.699997
# 2     266.579987
# 3     267.079987
# 4     253.850006
# ...          ...
# 1004  401.970001
# 1005  432.959991
# 1006  448.250000
# 1007  421.440002
# 1008  407.309998
#
# [1009 rows x 1 columns]

# %%
dt
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# ...

# %%
dt.loc[[3]]
# Out:
#          Date        Open        High    Low       Close   Adj Close   Volume
# 3  2018-02-08  267.079987  267.619995  250.0  250.100006  250.100006  9306700

# %%
dt.loc[[3],'Open']
# Out:
# 3    267.079987
# Name: Open, dtype: float64

# %%
dt[dt['Adj Close'].isna()]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
dt.iloc[1,:]
# Out:
# Date         2018-02-06
# Open         247.699997
# High         266.700012
# Low               245.0
# Close        265.720001
# Adj Close    265.720001
# Volume         12595800
# Name: 1, dtype: object

# %%
dth=plt.plot(dt['High'])
dtl=plt.plot(dt['Low'],color='red')

# %%
dt.groupby(['High']).count()
# Out:
#             Date  Open  Low  Close  Adj Close  Volume
# High
# 250.649994     1     1    1      1          1       1
# 254.500000     1     1    1      1          1       1
# 255.589996     1     1    1      1          1       1
# 255.800003     1     1    1      1          1       1
# 259.149994     1     1    1      1          1       1
# ...          ...   ...  ...    ...        ...     ...
# 689.969971     1     1    1      1          1       1
# 690.969971     1     1    1      1          1       1
# 691.739990     1     1    1      1          1       1
# 694.159973     1     1    1      1          1       1
# 700.989990     1     1    1      1          1       1
#
# [983 rows x 6 columns]

# %%
dt['Volume'].mean()
# Out:
# 7570685.03468781

# %%
dt['High'].mean()
# Out:
# 425.3207030802775

# %%
# %matplotlib inline
dt3=dt.plot(x='Date',y='Close',kind='line')
dt3
# Out:
# <Axes: xlabel='Date'>

# %%
dt['result']= dt['Open']-dt['Close']
dt
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume     result
# ...

# %%
dt['qty']=dt['Volume']/dt['Close']
dt
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume     result           qty
# ...

# %%
dt.drop(['qty'],axis=1,inplace=True)
dt
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume     result
# ...

# %%
dt['Date']=pd.to_datetime(dt['Date'])
dt['year']=dt['Date'].dt.year
dt['month']=dt['Date'].dt.month
dt['day']=dt['Date'].dt.day
dt.drop(['Date'],axis=1,inplace=True)
dt.head()
# Out:
#          Open        High         Low       Close   Adj Close    Volume  \
# 0  262.000000  267.899994  250.029999  254.259995  254.259995  11896100
# 1  247.699997  266.700012  245.000000  265.720001  265.720001  12595800
# 2  266.579987  272.450012  264.329987  264.559998  264.559998   8981500
# 3  267.079987  267.619995  250.000000  250.100006  250.100006   9306700
# 4  253.850006  255.800003  236.110001  249.470001  249.470001  16906900
#
#       result  year  month  day
# 0   7.740005  2018      2    5
# 1 -18.020004  2018      2    6
# 2   2.019989  2018      2    7
# 3  16.979981  2018      2    8
# 4   4.380005  2018      2    9

# %%
x=dt.iloc[:,:3]
x
y=dt['Close']
y
# Out:
# 0       254.259995
# 1       265.720001
# 2       264.559998
# 3       250.100006
# 4       249.470001
#            ...
# 1004    427.140015
# 1005    457.130005
# 1006    429.480011
# 1007    405.600006
# 1008    410.170013
# Name: Close, Length: 1009, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
model.predict(x_train)
# Out:
# array([341.43608775, 364.30306009, 391.8746111 , 547.96565313,
#        361.72537171, 492.66322283, 285.43807064, 275.73784581,
#        420.47021126, 636.69701592, 314.51568628, 294.12189443,
#        552.86370632, 486.22643625, 521.28251406, 513.34602362,
#        323.99963297, 328.56679259, 296.22484397, 518.09438404,
#        517.43482001, 392.63265693, 364.33462129, 628.72069287,
#        538.77400312, 375.69032132, 307.91585302, 270.42056541,
#        332.369557  , 414.74688475, 295.70353589, 378.16996466,
#        551.5131906 , 293.67626832, 332.69648136, 362.38843168,
#        349.60693711, 375.92358865, 365.77698263, 586.0842425 ,
#        540.83307898, 608.91179477, 345.43542881, 364.20530355,
#        550.47435949, 328.2013888 , 366.64777071, 346.16067036,
#        378.87617841, 367.46036904, 616.70569328, 501.76519377,
#        265.81853821, 367.99536237, 344.90557971, 267.23154969,
#        485.12933399, 479.99688723, 515.07861366, 394.24263394,
# ...

# %%
dat={'Open':[253],'High':[255],'Low':[236]}
model.predict(pd.DataFrame(dat))
# Out:
# array([241.78351727])
